# %%
1

# %%
2

# %%
3

# %%
4

# %%
import pandas as pd

df = pd.DataFrame({'col1': [1, 2, 3], 'col2': [4, 5, 6]})
df

# %%
from lets_plot import * 
ggplot() + \
geom_line(aes(x="col1", y="col2"), data=df, sampling="none" if df.size < 2500 else sampling_systematic(n=2500)) + \
geom_line(aes(x="col2", y="col1"), data=df, sampling="none" if df.size < 2500 else sampling_systematic(n=2500)) + \
geom_line(aes(x="col2", y="col2"), data=df, sampling="none" if df.size < 2500 else sampling_systematic(n=2500)) + \
ggtitle("Chart")

# %%
dropdown_1 = None
