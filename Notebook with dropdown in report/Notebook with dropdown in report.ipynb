# %%
category = "Category 1"

# %%
# import time
# time.sleep(5)

left_values = (
    ['Val 1', 'Val 2', 'Val 3']
    if category == 'Category 1' else
    ['Val 4', 'Val 5', 'Val 6']
    if category == 'Category 2' else
    ['Val 7']
)

# %%
left = left_values[1]

# %%
import time
time.sleep(50000)
