# %% [markdown]
# # Sheet

# %%
23231

# %%
123123123

# %%
import pandas as pd

data = {
    "Index": [1, 2, 3],
    "Numbers": [133, 23231, 123123123],
}
df = pd.DataFrame(data)

df

# %%
from lets_plot import * 
ggplot() + \
geom_line(aes(x="Index", y="Numbers"), data=df, sampling="none" if df.size < 2500 else sampling_systematic(n=2500)) + \
ggtitle("Chart")

# %%
import plotly.express as px
fig = px.bar(x=["a", "b", "c"], y=[1, 3, 2])
fig.show()

# %% [markdown]
# # Group

# %% [markdown]
# ## One more

# %%
print(2)

# %%
print(2)

# %% [markdown]
# ## еук

# %%
dropdown_1 = "one"

# %%
text_1 = "value"

# %%
import time

time.sleep(5)

# %%
1 / 0

# %% [markdown]
# # Sheet 2

# %% [markdown]
# # test
# wrwerwr
