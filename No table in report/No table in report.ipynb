# %%
import pandas as pd
import numpy as np

# Generate a random DataFrame with 5 rows and 3 columns
df = pd.DataFrame(
    np.random.rand(5, 3),  # Random numbers between 0 and 1
    columns=['Column1', 'Column2', 'Column3']
)

print("Generated Random DataFrame:")
df

# %%
# Generate a random DataFrame with 5 rows and 3 columns
df = pd.DataFrame(
    np.random.rand(1000, 37),  # Random numbers between 0 and 1
    columns=[
        'Column1', 'Column2', 'Column3', 'ffff','fwrefewrf','fwerwgwtre','wergwergerwg','wergwergwergewrg','caef', 'vrtve'
        'acd', 'Colucdsmn2', 'Cosfvalumn3', 'fvefvfff','fwrefvaefvewrf','fwerwvaefvgwtre','vaf','wergwvfvgbergwergewrg','cabbtbtef', 'nnn'
        'Colutuvfuumn3', 'Colauvfumn2', 'Colukajvcmn3', 'hverhffff','fwrefevhervhwrf','fwerakewcewgwtre','wergwerverbvhgerwg','wergweruafvngwergewrg','cavherbef', 'vrtvterwvve'
        'Chveolumn1', 'Colhvaeumn2', 'Columlvkqrjvn3', 'ffvrwejveff','fwvrewhvrefewrf','fwerwervhhwegwtre','wergewrghvgewwergerwg','wehrvewrv','qexqw', 'vrtqef5rve'
    ]
)

print("Generated Random DataFrame:")
df
