# %%
import pandas as pd
_df = pd.DataFrame([['1', 2, 3], ['4', 5, 6]])
_df = _df.rename(columns={k: 'tvl_%s' for k in _df.columns if k != 'tvl'})
_df

# %%
import pandas as pd
_df = pd.DataFrame([['1', 2, 3], ['4', 5, 6]])
_df
