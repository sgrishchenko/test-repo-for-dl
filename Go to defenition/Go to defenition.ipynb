# %% [markdown]
# # Sheet

# %%
def foo():
    1 / 0
    pass

# %%
foo()

# %%
foo()

# %%
import time

time.sleep(5)

# %% [markdown]
# ### group

# %%
1 / 0

# %%
"Some unique phrase"

# %% [markdown]
# ### other group

# %% [markdown]
# #### ррр

# %%
import pandas as pd

df = pd.DataFrame({ 'col1': [1, 2, 3], 'col2': [4, 6, 5]})
df

# %%
select * from df

# %% [markdown]
# # Sheet 2
