# %%
133

# %%
23231

# %%
123123123

# %%
import pandas as pd

data = {"Numbers": [133, 23231, 123123123]}
df = pd.DataFrame(data)

df

# %%
1 / 0

# %% [markdown]
# # Group

# %% [markdown]
# ## One more

# %%
print(2)

# %%
print(2)

# %% [markdown]
# ## еук
